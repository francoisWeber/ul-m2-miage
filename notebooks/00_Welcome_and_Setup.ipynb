# %% [markdown]
# # Welcome to Data Engineering Workshop
#
# ## Overview
#
# This workshop will introduce you to modern data engineering tools and practices using a real-world beer dataset.
#
# ### Available Tools
#
# 1. **MySQL** - Relational database
# 2. **Apache Spark (PySpark)** - Distributed data processing
# 3. **Redis** - In-memory key-value store
# 4. **Qdrant** - Vector database for embeddings
# 5. **Vespa** - Search engine and serving platform
# 6. **MinIO (S3)** - Object storage

# %%
import os
import sys

print(f"Python version: {sys.version}")
print(f"\nEnvironment variables:")

env_vars = ['MYSQL_HOST', 'MYSQL_DATABASE', 'REDIS_HOST', 'QDRANT_HOST', 'SPARK_MASTER', 'S3_ENDPOINT']
for var in env_vars:
    print(f"  {var}: {os.getenv(var, 'NOT SET')}")
