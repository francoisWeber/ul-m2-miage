# %% [markdown]
# # Check S3

# %%
# %env AWS_ENDPOINT_URL=http://minio:9000
# Out:
# env: AWS_ENDPOINT_URL=http://minio:9000

# %%
import pandas as pd

# %%
df = pd.read_csv("s3://beer-dataset/csv/beers.csv")
df
# Out:
#         id  brewery_id                    name  cat_id  style_id  abv  ibu  \
# 0        1         812             Hocus Pocus      11       116  4.5  0.0
# 1        2         264       Grimbergen Blonde      -1        -1  6.7  0.0
# 2        3         779  Widdershins Barleywine      -1        -1  9.1  0.0
# 3        4         287                 Lucifer      -1        -1  8.5  0.0
# 4        5        1056                  Bitter      -1        -1  4.0  0.0
# ...    ...         ...                     ...     ...       ...  ...  ...
# 5896  5910          10           Honey Rye Ale      11       128  0.0  0.0
# 5897  5911          10              Strawberry      11       121  0.0  0.0
# 5898  5912          10             Satsuma Wit      11       121  0.0  0.0
# 5899  5913        1422               Abhi beer       7        89  0.0  0.0
# 5900  5914        1423                    Ambr      11       132  0.0  0.0
#
# ...
